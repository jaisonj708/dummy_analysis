# %% [markdown]
# # Test R Notebook
#
# This is a simple notebook to test if the R kernel works in VS Code.
#
# **IMPORTANT**: Click "Select Kernel" in the top-right corner and choose **R** (not Python)!

# %%
# Basic R operations
print("Hello from R!")
x <- 1:10
print(x)

# %%
# Simple calculations
sum(1:100)
mean(c(10, 20, 30, 40, 50))

# %%
# Create a simple plot
plot(1:10, (1:10)^2, type="b", col="blue", main="Simple Plot", xlab="X", ylab="Y")

# %%
# Data frame example
df <- data.frame(
  name = c("Alice", "Bob", "Charlie"),
  age = c(25, 30, 35),
  score = c(85, 92, 78)
)
print(df)
summary(df)
